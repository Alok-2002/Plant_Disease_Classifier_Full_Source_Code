# %% [markdown]
# # 1.Importing Modules

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import Sequential
from tensorflow.keras.activations import sigmoid
from keras.optimizers import Adam

# %% [markdown]
# # 2.Defining Batch Size, Image Dimensions, Channles And Epochs

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS = 3
EPOCHS = 50

# %% [markdown]
# # 3.Loading Dataset From Image Directory Into A Variable

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Plant_images",
    batch_size=BATCH_SIZE,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    shuffle=True,
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
plt.figure(figsize=(10,10))
for image_batch, labels_batch in dataset.take(1):
  print(image_batch.shape)
  print(labels_batch.numpy)
  for i in range(12):
    ax = plt.subplot(3,4, i+1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    plt.title(class_names[labels_batch[i]])
    plt.axis("off")
# Out:
# (32, 256, 256, 3)
# <bound method _EagerTensorBase.numpy of <tf.Tensor: shape=(32,), dtype=int32, numpy=
# array([1, 1, 1, 1, 1, 0, 0, 0, 2, 0, 0, 0, 1, 0, 0, 1, 1, 0, 2, 1, 1, 1,
#        1, 1, 2, 0, 2, 0, 1, 1, 0, 0])>>

# %% [markdown]
# # 4. Defining Size For Training Data, Test Data, Validation Data From The Main Dataset

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size= 0.1
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
val_ds = train_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 8

# %% [markdown]
# # 5. Function To Get The Data

# %%
def get_dataset_partition_tf(ds, train_split= 0.8, val_split=0.1, test_split=0.1, shuffle =True, shuffle_size = 10000):
  assert(train_split+test_split+val_split) == 1
  ds_size = len(ds)
  if shuffle:
    ds = ds.shuffle(shuffle_size, seed = 12)
  train_size = int(train_split*ds_size)
  val_size = int(val_split*ds_size)

  train_ds = ds.take(train_size)
  val_ds = ds.skip(train_size).take(val_size)
  test_ds = ds.skip(train_size).skip(val_size)

  return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partition_tf(dataset)

# %%
print("Size Of Train Dataset is : ",len(train_ds))
print("Size Of validation Dataset is :",len(val_ds))
print("Size Of Test Dataset is :",len(test_ds))
# Out:
# Size Of Train Dataset is :  54
# Size Of validation Dataset is : 6
# Size Of Test Dataset is : 8

# %% [markdown]
# # 6. Preprocessing And Normalizing Data

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = t=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
for image_batch, labels_batch in dataset.take(1):
  print(image_batch[0].numpy()/255)
# Out:
# [[[0.5568628  0.54509807 0.5882353 ]
#   [0.5176471  0.5058824  0.54901963]
#   [0.49019608 0.47843137 0.52156866]
#   ...
#   [0.5019608  0.49411765 0.5372549 ]
#   [0.5019608  0.49411765 0.5372549 ]
#   [0.50980395 0.5019608  0.54509807]]
#
#  [[0.5137255  0.5019608  0.54509807]
#   [0.4862745  0.4745098  0.5176471 ]
#   [0.4745098  0.4627451  0.5058824 ]
#   ...
#   [0.49411765 0.4862745  0.5294118 ]
#   [0.5254902  0.5176471  0.56078434]
#   [0.5647059  0.5568628  0.6       ]]
#
#  [[0.50980395 0.49803922 0.5411765 ]
#   [0.49411765 0.48235294 0.5254902 ]
#   [0.49411765 0.48235294 0.5254902 ]
#   ...
#   [0.49411765 0.4862745  0.5294118 ]
#   [0.5058824  0.49803922 0.5411765 ]
#   [0.53333336 0.5254902  0.5686275 ]]
#
#  ...
#
#  [[0.7254902  0.7176471  0.7607843 ]
#   [0.74509805 0.7372549  0.78039217]
#   [0.7529412  0.74509805 0.7882353 ]
#   ...
#   [0.65882355 0.6509804  0.7019608 ]
#   [0.65882355 0.6509804  0.7019608 ]
#   [0.65882355 0.6509804  0.7019608 ]]
#
#  [[0.7294118  0.72156864 0.7647059 ]
#   [0.74509805 0.7372549  0.78039217]
#   [0.7490196  0.7411765  0.78431374]
#   ...
#   [0.65882355 0.6509804  0.7019608 ]
#   [0.65882355 0.6509804  0.7019608 ]
#   [0.6509804  0.6431373  0.69411767]]
#
#  [[0.7411765  0.73333335 0.7764706 ]
#   [0.74509805 0.7372549  0.78039217]
#   [0.7372549  0.7294118  0.77254903]
#   ...
#   [0.64705884 0.6392157  0.6901961 ]
#   [0.6392157  0.6313726  0.68235296]
#   [0.6313726  0.62352943 0.6745098 ]]]

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
]
)

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
]
)

# %% [markdown]
# # 7. Model Building

# %%
input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, kernel_size=(3,3),activation='relu',input_shape=input_shape),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64, kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64, kernel_size=(3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64, (3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64, (3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(64, (3,3),activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])

model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (32, 256, 256, 3)         0
#
#  sequential_5 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d_12 (Conv2D)          (32, 254, 254, 32)        896
#
#  max_pooling2d_12 (MaxPooli  (32, 127, 127, 32)        0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (32, 125, 125, 64)        18496
#
#  max_pooling2d_13 (MaxPooli  (32, 62, 62, 64)          0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (32, 60, 60, 64)          36928
#
#  max_pooling2d_14 (MaxPooli  (32, 30, 30, 64)          0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (32, 28, 28, 64)          36928
#
#  max_pooling2d_15 (MaxPooli  (32, 14, 14, 64)          0
#  ng2D)
#
#  conv2d_16 (Conv2D)          (32, 12, 12, 64)          36928
#
#  max_pooling2d_16 (MaxPooli  (32, 6, 6, 64)            0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (32, 4, 4, 64)            36928
#
#  max_pooling2d_17 (MaxPooli  (32, 2, 2, 64)            0
#  ng2D)
#
#  flatten_2 (Flatten)         (32, 256)                 0
#
#  dense_4 (Dense)             (32, 64)                  16448
#
#  dense_5 (Dense)             (32, 3)                   195
#
# =================================================================
# Total params: 183747 (717.76 KB)
# Trainable params: 183747 (717.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 8. Model Compiling

# %%
optimizer = Adam(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %% [markdown]
# # 9. Model Trainig On Dataset

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS
)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.0640 - accuracy: 0.9803 - val_loss: 0.0226 - val_accuracy: 0.9896
# Epoch 2/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0869 - val_accuracy: 0.9844
# Epoch 3/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0322 - accuracy: 0.9890 - val_loss: 0.1255 - val_accuracy: 0.9792
# Epoch 4/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 0.0399 - val_accuracy: 0.9844
# Epoch 5/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0250 - accuracy: 0.9913 - val_loss: 0.1496 - val_accuracy: 0.9740
# Epoch 6/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0240 - accuracy: 0.9936 - val_loss: 0.0873 - val_accuracy: 0.9844
# Epoch 7/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0328 - accuracy: 0.9913 - val_loss: 0.0920 - val_accuracy: 0.9792
# Epoch 8/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.0208 - accuracy: 0.9925 - val_loss: 0.1778 - val_accuracy: 0.9479
# Epoch 9/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0186 - accuracy: 0.9959 - val_loss: 0.0570 - val_accuracy: 0.9948
# Epoch 10/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.1099 - val_accuracy: 0.9896
# Epoch 11/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 0.0749 - val_accuracy: 0.9792
# Epoch 12/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0727 - accuracy: 0.9728 - val_loss: 0.0783 - val_accuracy: 0.9792
# Epoch 13/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 0.0619 - val_accuracy: 0.9948
# Epoch 14/50
# 54/54 [==============================] - 57s 1s/step - loss: 0.0243 - accuracy: 0.9954 - val_loss: 0.0507 - val_accuracy: 0.9948
# Epoch 15/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0644 - accuracy: 0.9774 - val_loss: 0.0307 - val_accuracy: 0.9896
# Epoch 16/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0183 - accuracy: 0.9959 - val_loss: 0.0544 - val_accuracy: 0.9948
# Epoch 17/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 0.0730 - val_accuracy: 0.9844
# Epoch 18/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0111 - accuracy: 0.9983 - val_loss: 0.0530 - val_accuracy: 0.9948
# Epoch 19/50
# 54/54 [==============================] - 58s 1s/step - loss: 0.0116 - accuracy: 0.9942 - val_loss: 0.0618 - val_accuracy: 0.9844
# Epoch 20/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0336 - accuracy: 0.9907 - val_loss: 0.0414 - val_accuracy: 0.9948
# Epoch 21/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0315 - accuracy: 0.9884 - val_loss: 0.0621 - val_accuracy: 0.9844
# Epoch 22/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0217 - accuracy: 0.9936 - val_loss: 0.0285 - val_accuracy: 0.9948
# Epoch 23/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0203 - accuracy: 0.9936 - val_loss: 0.1679 - val_accuracy: 0.9479
# Epoch 24/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0308 - val_accuracy: 0.9896
# Epoch 25/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.0443 - val_accuracy: 0.9948
# Epoch 26/50
# 54/54 [==============================] - 198s 4s/step - loss: 0.0223 - accuracy: 0.9948 - val_loss: 0.0677 - val_accuracy: 0.9948
# Epoch 27/50
# 54/54 [==============================] - 69s 1s/step - loss: 0.0273 - accuracy: 0.9907 - val_loss: 0.0919 - val_accuracy: 0.9635
# Epoch 28/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0121 - accuracy: 0.9971 - val_loss: 0.0412 - val_accuracy: 0.9948
# Epoch 29/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0078 - accuracy: 0.9983 - val_loss: 0.0362 - val_accuracy: 0.9948
# Epoch 30/50
# 54/54 [==============================] - 70s 1s/step - loss: 0.0071 - accuracy: 0.9988 - val_loss: 0.0354 - val_accuracy: 0.9948
# Epoch 31/50
# 54/54 [==============================] - 69s 1s/step - loss: 0.0338 - accuracy: 0.9925 - val_loss: 0.0630 - val_accuracy: 0.9844
# Epoch 32/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.0082 - val_accuracy: 0.9948
# Epoch 33/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.0692 - val_accuracy: 0.9896
# Epoch 34/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0162 - accuracy: 0.9936 - val_loss: 0.0732 - val_accuracy: 0.9792
# Epoch 35/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0090 - accuracy: 0.9954 - val_loss: 0.0096 - val_accuracy: 0.9948
# Epoch 36/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.0344 - val_accuracy: 0.9948
# Epoch 37/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 0.0116 - val_accuracy: 0.9948
# Epoch 38/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0415 - accuracy: 0.9850 - val_loss: 0.0546 - val_accuracy: 0.9896
# Epoch 39/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0168 - accuracy: 0.9931 - val_loss: 0.0902 - val_accuracy: 0.9948
# Epoch 40/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0607 - val_accuracy: 0.9844
# Epoch 41/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0156 - accuracy: 0.9942 - val_loss: 0.0485 - val_accuracy: 0.9844
# Epoch 42/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0244 - accuracy: 0.9913 - val_loss: 0.0557 - val_accuracy: 0.9948
# Epoch 43/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.0515 - val_accuracy: 0.9896
# Epoch 44/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.0650 - val_accuracy: 0.9688
# Epoch 45/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0639 - val_accuracy: 0.9948
# Epoch 46/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0110 - accuracy: 0.9977 - val_loss: 0.0815 - val_accuracy: 0.9844
# Epoch 47/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0374 - accuracy: 0.9855 - val_loss: 0.0854 - val_accuracy: 0.9740
# Epoch 48/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0085 - accuracy: 0.9983 - val_loss: 0.0609 - val_accuracy: 0.9896
# Epoch 49/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0146 - accuracy: 0.9948 - val_loss: 0.0630 - val_accuracy: 0.9948
# Epoch 50/50
# 54/54 [==============================] - 60s 1s/step - loss: 0.0134 - accuracy: 0.9965 - val_loss: 0.0343 - val_accuracy: 0.9948

# %%
len(test_ds)
# Out:
# 8

# %%
scores = model.evaluate(test_ds)
print(scores)
# Out:
# 8/8 [==============================] - 5s 547ms/step - loss: 0.0371 - accuracy: 0.9883
# [0.03713809326291084, 0.98828125]

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 54}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS),acc, label="Training Accuracy")
plt.plot(range(EPOCHS), val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training And Validation Accuracy")

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label="Training Loss")
plt.plot(range(EPOCHS), val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Training And Validation Loss")
plt.show()

# %%
import numpy as np

for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype("uint8")

    print("First Image To Predict ")
    plt.imshow(first_image)
    print("Actual Label: ",class_names[labels_batch[0].numpy()]) 


    batch_prediction = model.predict(images_batch)
    print("Predicted Label :",class_names[np.argmax(batch_prediction[0])])
# Out:
# First Image To Predict
# Actual Label:  Potato___Early_blight
# 1/1 [==============================] - 1s 984ms/step
# Predicted Label : Potato___Early_blight

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))

for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3 , i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class, confidence  = predict(model, images[i].numpy())
    
        actual_class = class_names[labels[i]]
        plt.title(f"Actual: {actual_class}, \n Predicted: {predicted_class}. \n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 87ms/step

# %%
import os 
model_version = max([int(i) for i in (os.listdir("../models")+[0])]) + 1
model.save(f"../models/{model_version}")
# Out:
# INFO:tensorflow:Assets written to: ../models/2\assets
# INFO:tensorflow:Assets written to: ../models/2\assets

# %%
model_version = 1
# Out:
# INFO:tensorflow:Assets written to: ../models/1\assets
# INFO:tensorflow:Assets written to: ../models/1\assets
